# %%
import pandas as pd
import numpy as np
import json
import joblib
from tensorflow.keras.models import model_from_json

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 100)

# %%
experi = pd.read_csv('results_text/NN_experiments_with_1.0data.csv')

# %%
experi
# Out:
#     best_dev_mse  \
# 0       0.040176
# 1       0.039685
# 2       0.116993
# 3       0.040592
# 4       0.041188
# 5       0.040380
# 6       0.041354
# 7       0.040116
# 8       0.055268
# 9       0.046960
# 10      0.058516
# 11      0.041068
# 12      0.041208
# 13      0.041276
# 14      0.040070
# 15      0.040388
# 16      0.046269
# 17      0.040698
# 18      0.041696
# 19      0.039841
# 20      0.040614
# 21      0.040720
# 22      0.040612
# 23      0.061183
# 24      0.045228
# 25      0.041380
# 26      0.055685
# 27      0.041552
# 28      0.050940
# 29      0.041562
# 30      0.040695
# 31      0.053541
# 32      0.057486
# 33      0.041749
# 34      0.041483
# 35      0.040780
# 36      0.048164
# 37      0.040405
# 38      0.039854
# 39      0.040628
# 40      0.041715
# 41      0.040294
# 42      0.040515
# 43      0.041169
# 44      0.041039
# 45      0.040410
# 46      0.041529
# 47      0.051934
# 48      0.041245
# 49      0.040932
#
#                                                                                                 history  \
# 0   {'val_mean_squared_error': [0.044635985, 0.042633563, 0.04189414, 0.0415638, 0.041492645, 0.0414...
# 1   {'val_mean_squared_error': [0.048587285, 0.04401901, 0.042268645, 0.04199894, 0.041528992, 0.041...
# 2   {'val_mean_squared_error': [0.50957346, 0.45504653, 0.41845152, 0.39303455, 0.37486884, 0.361404...
# 3   {'val_mean_squared_error': [0.04859825, 0.044959173, 0.04327607, 0.04249443, 0.04215105, 0.04245...
# 4   {'val_mean_squared_error': [0.05727915, 0.04994306, 0.04733892, 0.045971356, 0.045043483, 0.0442...
# 5   {'val_mean_squared_error': [0.043713253, 0.042291652, 0.041285276, 0.040602446, 0.042868633, 0.0...
# 6   {'val_mean_squared_error': [0.16758287, 0.1067648, 0.083396055, 0.07168693, 0.0646194, 0.0597429...
# 7   {'val_mean_squared_error': [0.044607293, 0.04366337, 0.04330147, 0.04226908, 0.04116173, 0.04155...
# 8   {'val_mean_squared_error': [0.32574654, 0.27669334, 0.25325617, 0.23583959, 0.2206496, 0.2067769...
# 9   {'val_mean_squared_error': [0.15561864, 0.124088675, 0.10553471, 0.09287058, 0.08423009, 0.07824...
# 10  {'val_mean_squared_error': [0.24828672, 0.21692789, 0.1952207, 0.17922324, 0.16690291, 0.1572233...
# 11  {'val_mean_squared_error': [0.049682226, 0.04531447, 0.043646988, 0.04275982, 0.042664554, 0.041...
# 12  {'val_mean_squared_error': [0.05651603, 0.04898417, 0.046295624, 0.044811513, 0.04378451, 0.0434...
# 13  {'val_mean_squared_error': [0.0970784, 0.071243316, 0.059665855, 0.0542884, 0.050649755, 0.04899...
# 14  {'val_mean_squared_error': [0.04927827, 0.045626633, 0.044481356, 0.043746185, 0.043312844, 0.04...
# 15  {'val_mean_squared_error': [0.043619435, 0.042880245, 0.04124462, 0.041689932, 0.042209517, 0.04...
# 16  {'val_mean_squared_error': [0.21218227, 0.15252957, 0.123982355, 0.10736467, 0.09638707, 0.08919...
# 17  {'val_mean_squared_error': [0.049830496, 0.045545943, 0.044773288, 0.04305607, 0.042743254, 0.04...
# 18  {'val_mean_squared_error': [0.12907405, 0.08853666, 0.07264211, 0.06389659, 0.0588234, 0.0552780...
# 19  {'val_mean_squared_error': [0.044237938, 0.04207077, 0.041380152, 0.040764414, 0.040514372, 0.04...
# 20  {'val_mean_squared_error': [0.05483191, 0.047197606, 0.044690084, 0.04628751, 0.04353375, 0.0425...
# 21  {'val_mean_squared_error': [0.058151677, 0.050447494, 0.047454253, 0.045788344, 0.044912368, 0.0...
# 22  {'val_mean_squared_error': [0.052660175, 0.046930324, 0.044888303, 0.043480653, 0.04312297, 0.04...
# 23  {'val_mean_squared_error': [0.3500333, 0.31010503, 0.2865392, 0.26973438, 0.25621566, 0.24432488...
# 24  {'val_mean_squared_error': [0.19492969, 0.14041062, 0.115062006, 0.09909093, 0.08917788, 0.08251...
# 25  {'val_mean_squared_error': [0.055228278, 0.04808163, 0.045137987, 0.044580426, 0.043469507, 0.04...
# 26  {'val_mean_squared_error': [0.23260775, 0.19326898, 0.17140178, 0.15755478, 0.14797305, 0.140886...
# 27  {'val_mean_squared_error': [0.0512632, 0.047636617, 0.046750255, 0.04526425, 0.04464504, 0.04407...
# 28  {'val_mean_squared_error': [0.18656702, 0.16593745, 0.15250297, 0.14161402, 0.13218822, 0.123939...
# 29  {'val_mean_squared_error': [0.40341613, 0.27769068, 0.21580298, 0.17703393, 0.14858627, 0.130185...
# 30  {'val_mean_squared_error': [0.0529953, 0.04757922, 0.045406524, 0.044227295, 0.043129884, 0.0427...
# 31  {'val_mean_squared_error': [0.28216413, 0.24313852, 0.21795352, 0.19830441, 0.1817622, 0.168618,...
# 32  {'val_mean_squared_error': [0.24217208, 0.2174271, 0.198718, 0.18394364, 0.17180413, 0.161639, 0...
# 33  {'val_mean_squared_error': [0.061560646, 0.052396633, 0.04840967, 0.046216007, 0.044936303, 0.04...
# 34  {'val_mean_squared_error': [0.14041555, 0.09049764, 0.06991535, 0.059937455, 0.053825084, 0.0500...
# 35  {'val_mean_squared_error': [0.052613232, 0.046478655, 0.044537216, 0.043361854, 0.042810626, 0.0...
# 36  {'val_mean_squared_error': [0.24852675, 0.18998013, 0.16096124, 0.14093801, 0.12614419, 0.114668...
# 37  {'val_mean_squared_error': [0.043813698, 0.042848993, 0.042277735, 0.043011412, 0.041513983, 0.0...
# 38  {'val_mean_squared_error': [0.042841125, 0.042044885, 0.04091211, 0.041795943, 0.04057649, 0.040...
# 39  {'val_mean_squared_error': [0.046441406, 0.043708578, 0.043610226, 0.0428524, 0.041750297, 0.042...
# 40  {'val_mean_squared_error': [0.11207148, 0.083344184, 0.07180663, 0.065025866, 0.061322164, 0.058...
# 41  {'val_mean_squared_error': [0.11536708, 0.08604743, 0.074899174, 0.06850597, 0.065299466, 0.0619...
# 42  {'val_mean_squared_error': [0.049244326, 0.045501888, 0.044019762, 0.043208122, 0.042688165, 0.0...
# 43  {'val_mean_squared_error': [0.0688187, 0.05468728, 0.04921441, 0.04725539, 0.045716956, 0.044887...
# 44  {'val_mean_squared_error': [0.063928336, 0.052672345, 0.048746336, 0.04665597, 0.045411292, 0.04...
# 45  {'val_mean_squared_error': [0.052254677, 0.046551064, 0.043865282, 0.042856324, 0.043004137, 0.0...
# 46  {'val_mean_squared_error': [0.08415788, 0.064938545, 0.057022672, 0.05281206, 0.050241105, 0.048...
# 47  {'val_mean_squared_error': [0.21883507, 0.19099754, 0.17571838, 0.16403592, 0.15397348, 0.145069...
# 48  {'val_mean_squared_error': [0.052057844, 0.04692567, 0.045217045, 0.044183776, 0.04344213, 0.042...
# 49  {'val_mean_squared_error': [0.1513475, 0.10113706, 0.07822785, 0.06719953, 0.060978282, 0.056996...
#
#                                                                                    hyperparam
# 0   {'lr': 0.00020537723995292504, 'opt': 'rmsprop', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 1        {'lr': 0.0004479965753916489, 'opt': 'adam', 'n_fc_layers': 3, 'fc_hidden_size': 64}
# 2       {'lr': 1.1896603309727652e-05, 'opt': 'sgd', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 3   {'lr': 0.00021839256556034894, 'opt': 'rmsprop', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 4   {'lr': 2.5979485589616436e-05, 'opt': 'rmsprop', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 5    {'lr': 0.0008892729296914218, 'opt': 'rmsprop', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 6       {'lr': 1.3922612921719966e-05, 'opt': 'adam', 'n_fc_layers': 4, 'fc_hidden_size': 64}
# 7    {'lr': 0.0004279427726724609, 'opt': 'rmsprop', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 8       {'lr': 0.00013927054726819041, 'opt': 'sgd', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 9         {'lr': 0.0006971795880753261, 'opt': 'sgd', 'n_fc_layers': 4, 'fc_hidden_size': 64}
# 10        {'lr': 5.197540708912555e-05, 'opt': 'sgd', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 11       {'lr': 6.51563765694733e-05, 'opt': 'adam', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 12     {'lr': 4.2182136331456416e-05, 'opt': 'adam', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 13     {'lr': 2.6264764382796887e-05, 'opt': 'adam', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 14   {'lr': 0.00012388574604938846, 'opt': 'rmsprop', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 15     {'lr': 0.00088835908626832, 'opt': 'rmsprop', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 16        {'lr': 0.0007796545776588972, 'opt': 'sgd', 'n_fc_layers': 3, 'fc_hidden_size': 64}
# 17   {'lr': 9.863267451463615e-05, 'opt': 'rmsprop', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 18       {'lr': 1.733845097462554e-05, 'opt': 'adam', 'n_fc_layers': 4, 'fc_hidden_size': 64}
# 19       {'lr': 0.0007999198652207813, 'opt': 'adam', 'n_fc_layers': 3, 'fc_hidden_size': 64}
# 20      {'lr': 0.0001616513005302094, 'opt': 'adam', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 21    {'lr': 3.743239506061598e-05, 'opt': 'rmsprop', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 22   {'lr': 5.480876053781034e-05, 'opt': 'rmsprop', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 23        {'lr': 8.636839581433106e-05, 'opt': 'sgd', 'n_fc_layers': 3, 'fc_hidden_size': 64}
# 24       {'lr': 0.0009384616051663284, 'opt': 'sgd', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 25      {'lr': 5.975505453883684e-05, 'opt': 'adam', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 26       {'lr': 7.627907146174647e-05, 'opt': 'sgd', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 27   {'lr': 8.651062659050859e-05, 'opt': 'rmsprop', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 28       {'lr': 0.0001980918839625245, 'opt': 'sgd', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 29      {'lr': 1.1275809677085998e-05, 'opt': 'adam', 'n_fc_layers': 3, 'fc_hidden_size': 64}
# 30   {'lr': 9.476279254623556e-05, 'opt': 'rmsprop', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 31      {'lr': 0.00019721841487173997, 'opt': 'sgd', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 32          {'lr': 5.8841701508643e-05, 'opt': 'sgd', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 33        {'lr': 4.37424040191062e-05, 'opt': 'adam', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 34      {'lr': 2.732385098042677e-05, 'opt': 'adam', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 35       {'lr': 8.446439165297157e-05, 'opt': 'adam', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 36        {'lr': 0.0005396407192249501, 'opt': 'sgd', 'n_fc_layers': 3, 'fc_hidden_size': 64}
# 37   {'lr': 0.0003032872926505802, 'opt': 'rmsprop', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 38    {'lr': 0.0007047432497314169, 'opt': 'rmsprop', 'n_fc_layers': 4, 'fc_hidden_size': 64}
# 39   {'lr': 0.0001504515022268488, 'opt': 'rmsprop', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 40  {'lr': 1.6100164479630184e-05, 'opt': 'rmsprop', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 41   {'lr': 2.4256400443479462e-05, 'opt': 'rmsprop', 'n_fc_layers': 3, 'fc_hidden_size': 64}
# 42    {'lr': 0.0001233028234071078, 'opt': 'rmsprop', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 43   {'lr': 5.987284552677862e-05, 'opt': 'rmsprop', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 44   {'lr': 8.948894780107545e-05, 'opt': 'rmsprop', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 45     {'lr': 0.00024701866407172377, 'opt': 'adam', 'n_fc_layers': 3, 'fc_hidden_size': 128}
# 46       {'lr': 1.919542220342578e-05, 'opt': 'adam', 'n_fc_layers': 5, 'fc_hidden_size': 64}
# 47      {'lr': 0.00014696637777673766, 'opt': 'sgd', 'n_fc_layers': 4, 'fc_hidden_size': 128}
# 48     {'lr': 4.6827664439098106e-05, 'opt': 'adam', 'n_fc_layers': 5, 'fc_hidden_size': 128}
# 49      {'lr': 1.4727322990017119e-05, 'opt': 'adam', 'n_fc_layers': 4, 'fc_hidden_size': 64}

# %%
text_token = joblib.load('encoded_data_text/text_1_vectorizer.pkl')

# %%
print(text_token)
# Out:
# None
